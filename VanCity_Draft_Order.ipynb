# %% [markdown]
# <font size="6"> Introduction </font>
#
# <font size="4" style="color:blue;">Draft Picks as of August 24, 2024 </font>
#
# <p>Here it is guys! The complete draft order for the upcoming 2024 draft. Picks will be updated as they change. Below are your available picks for 2025</p>

# %%
import pandas as pd

# %%
vc2024 = pd.read_csv('/Users/blairjdaniel/VENV/Vancity/DF/2024_actual.csv').style.set_properties(**{'text-align': 'left'})
vc2024
# Out:
# <style type="text/css">
# ...

# %%
vc2025 = pd.read_csv('/Users/blairjdaniel/VENV/Vancity/DF/2025.csv').style.set_properties(**{'text-align': 'left'})
vc2025
# Out:
# <style type="text/css">
# ...

# %%
# !pip install dataframe_image
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import dataframe_image as dfi

# vc2024 is your DataFrame
dfi.export(vc2024, 'vc2024_image.png')

# %%
import dataframe_image as dfi

# vc2024 is your DataFrame
dfi.export(vc2025, 'vc2025_image.png')
